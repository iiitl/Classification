# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('wines_SPA.csv')

# %%
df.head()
# Out:
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018     4.9           31  Espana
# 2   Vega Sicilia          Unico  2009     4.8         1793  Espana
# 3   Vega Sicilia          Unico  1999     4.8         1705  Espana
# 4   Vega Sicilia          Unico  1996     4.8         1309  Espana
#
#              region   price                  type  body  acidity
# 0              Toro  995.00              Toro Red   5.0      3.0
# 1    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0

# %%
df.shape
# Out:
# (7500, 11)

# %%
df.isna().sum()
# Out:
# winery            0
# wine              0
# year              2
# rating            0
# num_reviews       0
# country           0
# region            0
# price             0
# type            545
# body           1169
# acidity        1169
# dtype: int64

# %%
df['body'].unique()
# Out:
# array([ 5.,  4.,  3., nan,  2.])

# %%
df['acidity'].unique()
# Out:
# array([ 3.,  2.,  1., nan])

# %%
import math
median_body = math.floor(df.body.median())
median_acidity = math.floor(df.acidity.median())

# %%
df.body = df.body.fillna(median_body)

# %%
df.body.isna().sum()
# Out:
# 0

# %%
df.acidity = df.acidity.fillna(median_acidity)

# %%
df.acidity.isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# winery           0
# wine             0
# year             2
# rating           0
# num_reviews      0
# country          0
# region           0
# price            0
# type           545
# body             0
# acidity          0
# dtype: int64

# %%
df = df.dropna()
df.isna().sum()
# Out:
# winery         0
# wine           0
# year           0
# rating         0
# num_reviews    0
# country        0
# region         0
# price          0
# type           0
# body           0
# acidity        0
# dtype: int64

# %%
df.head(30)
# Out:
#                  winery                            wine  year  rating  \
# 0         Teso La Monja                           Tinto  2013     4.9
# 1                Artadi                   Vina El Pison  2018     4.9
# 2          Vega Sicilia                           Unico  2009     4.8
# 3          Vega Sicilia                           Unico  1999     4.8
# 4          Vega Sicilia                           Unico  1996     4.8
# 5          Vega Sicilia                           Unico  1998     4.8
# 6          Vega Sicilia                           Unico  2010     4.8
# 7          Vega Sicilia                           Unico  1995     4.8
# 8          Vega Sicilia  Unico Reserva Especial Edicion  2015     4.8
# 9          Vega Sicilia                           Unico  2011     4.8
# 10         Vega Sicilia  Unico Reserva Especial Edicion  2016     4.8
# 11  Pago de Carraovejas                       El Anejon  2016     4.8
# 12         Vega Sicilia  Unico Reserva Especial Edicion  2018     4.8
# 13         Vega Sicilia                           Unico  1970     4.8
# 14          Toro Albala       Don PX Convento Seleccion  1946     4.8
# 15  Pago de Carraovejas           Cuesta de Las Liebres  2015     4.8
# 16         Vega Sicilia                           Unico  1962     4.8
# 17         Vega Sicilia  Unico Reserva Especial Edicion  2019     4.8
# 18      Bodegas El Nido                         El Nido  2018     4.8
# 19         Vega Sicilia  Unico Reserva Especial Edicion  2004     4.8
# 20           Valdespino                Toneles Moscatel  N.V.     4.8
# 21         Vega Sicilia  Unico Reserva Especial Edicion  2013     4.8
# 22    Dominio de Pingus                          Pingus  2016     4.8
# 23          Toro Albala       Don PX Convento Seleccion  1931     4.8
# 24         Vega Sicilia  Unico Reserva Especial Edicion  2010     4.8
# 25         Vega Sicilia                           Unico  1979     4.8
# 26          Toro Albala            Don PX Pedro Ximenez  1946     4.8
# 27      Alvaro Palacios  L'Ermita Velles Vinyes Priorat  2004     4.8
# 28         Vega Sicilia  Unico Reserva Especial Edicion  2005     4.8
# 29         Vega Sicilia  Unico Reserva Especial Edicion  2020     4.8
#
#     num_reviews country              region       price                  type  \
# 0            58  Espana                Toro   995.00000              Toro Red
# 1            31  Espana      Vino de Espana   313.50000           Tempranillo
# 2          1793  Espana    Ribera del Duero   324.95000  Ribera Del Duero Red
# 3          1705  Espana    Ribera del Duero   692.96000  Ribera Del Duero Red
# 4          1309  Espana    Ribera del Duero   778.06000  Ribera Del Duero Red
# 5          1209  Espana    Ribera del Duero   490.00000  Ribera Del Duero Red
# 6          1201  Espana    Ribera del Duero   349.00000  Ribera Del Duero Red
# 7           926  Espana    Ribera del Duero   810.89000  Ribera Del Duero Red
# 8           643  Espana    Ribera del Duero   345.00000  Ribera Del Duero Red
# 9           630  Espana    Ribera del Duero   315.00000  Ribera Del Duero Red
# 10          591  Espana    Ribera del Duero   514.85000  Ribera Del Duero Red
# 11          454  Espana    Ribera del Duero   105.15000  Ribera Del Duero Red
# 12          438  Espana    Ribera del Duero   430.00000  Ribera Del Duero Red
# 13          417  Espana    Ribera del Duero   925.00000  Ribera Del Duero Red
# 14          398  Espana    Montilla-Moriles   350.00000         Pedro Ximenez
# 15          372  Espana    Ribera del Duero   166.18000  Ribera Del Duero Red
# 16          295  Espana    Ribera del Duero  1620.00000  Ribera Del Duero Red
# 17          250  Espana    Ribera del Duero   431.36000  Ribera Del Duero Red
# 18          217  Espana             Jumilla   195.62738                   Red
# 19          211  Espana    Ribera del Duero   824.43000  Ribera Del Duero Red
# 20          174  Espana  Jerez-Xeres-Sherry   253.00000                Sherry
# 21          172  Espana    Ribera del Duero   570.51000  Ribera Del Duero Red
# 22          145  Espana    Ribera del Duero  1280.00000  Ribera Del Duero Red
# 23          139  Espana    Montilla-Moriles   244.85000         Pedro Ximenez
# 24          125  Espana    Ribera del Duero   719.34000  Ribera Del Duero Red
# 25          118  Espana    Ribera del Duero   815.00000  Ribera Del Duero Red
# 26          103  Espana    Montilla-Moriles   285.86000         Pedro Ximenez
# 27           87  Espana            Priorato  1410.26000           Priorat Red
# 28           87  Espana    Ribera del Duero   813.96000  Ribera Del Duero Red
# 29           84  Espana    Ribera del Duero   435.75000  Ribera Del Duero Red
#
#     body  acidity
# 0    5.0      3.0
# 1    4.0      2.0
# 2    5.0      3.0
# 3    5.0      3.0
# 4    5.0      3.0
# 5    5.0      3.0
# 6    5.0      3.0
# 7    5.0      3.0
# 8    5.0      3.0
# 9    5.0      3.0
# 10   5.0      3.0
# 11   5.0      3.0
# 12   5.0      3.0
# 13   5.0      3.0
# 14   5.0      1.0
# 15   5.0      3.0
# 16   5.0      3.0
# 17   5.0      3.0
# 18   4.0      3.0
# 19   5.0      3.0
# 20   4.0      3.0
# 21   5.0      3.0
# 22   5.0      3.0
# 23   5.0      1.0
# 24   5.0      3.0
# 25   5.0      3.0
# 26   5.0      1.0
# 27   4.0      3.0
# 28   5.0      3.0
# 29   5.0      3.0

# %%
df.winery.unique()
# Out:
# array(['Teso La Monja', 'Artadi', 'Vega Sicilia', 'Pago de Carraovejas',
#        'Toro Albala', 'Bodegas El Nido', 'Valdespino',
#        'Dominio de Pingus', 'Alvaro Palacios', 'Ordonez',
#        'Bodegas Valduero', 'Vina Sastre', 'Sierra Cantabria',
#        'Descendientes de J. Palacios', 'La Rioja Alta',
#        'Marques de Murrieta', 'Vinedos de Paganos', 'Emilio Moro',
#        'Quinta de la Quietud', 'Bodegas Mauro',
#        'Bodega Contador (Benjamin Romeo)', 'Remirez de Ganuza',
#        'Bodegas San Roman', 'Pago de Los Capellanes', 'Bodega Numanthia',
#        'Alto Moncayo', 'Mas Doix', 'Bodegas Roda', 'Martinet', 'Recaredo',
#        'Clos Erasmus', 'Barbadillo', 'Gonzalez-Byass', 'Bodegas Amaren',
#        'Alvear', 'Equipo Navazos', 'Morca', 'Territorio Luthier',
#        'Terra Remota', 'Dehesa de Los Canonigos', 'Miguel Merino',
#        'Alion', 'Aalto', 'Carmelo Rodero', 'Dominio del Bendito',
#        "Mas d'en Gil", 'Casa Castillo', 'Matarromera', 'Nin-Ortiz',
#        'Vinas del Vero', 'Marques de Riscal', 'Arzuaga',
#        'Bodegas Mas Alta', 'Dominio de Calogia', 'Tomas Postigo',
#        'Cal Pla', 'Ossian', 'Cepa 21', 'Bodegas Vilano', 'Allende',
#        'Hacienda Monasterio', 'Castillo Perelada', 'Osborne', 'Ysios',
#        'Marques de Grinon', 'Contino', 'Gramona', 'Dominio del Aguila',
#        'Hacienda Solano', 'Anima Negra', 'Castano', 'La Legua',
#        'Castillo de Cuzcurrita', 'Oxer Wines', 'Bodegas Yuste',
#        'Bodegas 6o Elemento - Vino Sexto Elemento',
#        'Proyecto Garnachas de Espana', 'Vall Llach', 'Ukan Winery',
#        'Vina Real', 'Dominio de Atauta', 'Micro Bio (MicroBio)',
#        'Terroir Al Limit Soc. Lda', 'Finca Torremilanos',
#        'Huerta de Albala', 'Gomez Cruzado', "Castell d'Encus",
#        'Abadia Retuerta', 'Enate',
#        'Benjamin de Rothschild - Vega Sicilia', 'Bodegas Aragonesas',
#        'Acustic Celler', 'Vina Pedrosa', 'Pintia', 'Belondrade', 'Muga',
#        'Clos Mogador', 'Bodegas Tradicion', 'Senorio de San Vicente',
#        'Costers del Siurana', 'Francisco Barona', 'Juan Gil', 'Lan',
#        'R. Lopez de Heredia', 'Adama Wines', 'Milsetentayseis',
#        'Espectacle del Montsant', 'Tinto Pesquera', 'Ferrer Bobet',
#        'Familia Torres', 'Pazo Barrantes', 'Tio Pepe', 'Cruz de Alba',
#        'Dominio de Es', 'Jesus Madrazo', 'Bodegas Naluar & Acediano',
#        'Marques de Caceres', 'Trus', 'Mestres', 'Chivite', 'Bodega Ribas',
#        'Vinas del Cenit', 'Mas del Serral', 'Cervoles', 'Diez Merito',
#        'Marques de Burgos', 'Penafiel', 'Tobia', 'Tresmano - Tr3smano',
#        'Sei Solo', 'Finca Villacreces', 'Virgen de la Asuncion', 'Romate',
#        'Sara Perez y Rene Barbier', 'Dehesa del Carrizal', 'Tarsus',
#        'Beronia', 'Monte Real', 'Divina Proporcion',
#        'Vina al Lado de la Casa', 'Marques de la Concordia',
#        'Agusti Torello Mata', 'Dominio de Cair', 'Valquejigoso',
#        'Vizcarra', 'Legaris', 'Federico Paternina', 'Vinicola Real',
#        'Losada', "Clos d'Agon", 'Sacristia AB', 'Uvaguilera Aguilera',
#        'Emilio Hidalgo', 'Altos del Terral', 'El Regajal', 'Valderiz',
#        'Jose Pariente', 'Scala Dei', 'Bodegas Valdelana',
#        'Abel Mendoza Monge', 'Anayon', 'Sierra Salinas', 'Vinos Sanz',
#        'Cerro San Cristobal', 'Altos de Rioja',
#        'Bodegas Celler Francisco Castillo - Clos Dominic',
#        'La Vinya del Vuit', 'Venus la Universal', 'Pedralonga', 'Atalaya',
#        'Matsu', 'Marques de Vargas', 'Volver', 'Tridente', 'Ausas',
#        'Cillar de Silos', 'Imperial', 'Ramos-Paul', 'Bodega de Bardos',
#        'Rodriguez Sanzo', 'Antidoto', 'Bosque de Matasnos', 'Altanza',
#        'Remelluri', 'Perinet', 'La Vicalanda', 'Monovar', 'Alvaro Domecq',
#        'Los Aguilares', 'Bodega Rento', 'Marco Abella',
#        'Javier Sanz Viticultor', 'Protos', 'Harveys', 'Orben', 'Jaro',
#        'Bodegas Ximenez-Spinola', 'Mustiguillo', 'Vina Pomal', 'Astrales',
#        'Merum Priorati', 'Hacienda Lopez de Haro', 'Cayetano del Pino',
#        'Pazo Senorans', 'Fefinanes', 'Resalte', 'Figuero', 'Pinea',
#        'Portal del Priorat', 'Cims de Porrera', 'Casa Rojo', 'Murua',
#        'Vinyes Domenech', 'Pago de Vallegarcia', 'Eulogio Pomares',
#        'Sangenis I Vaque', 'Delgado Zuleta', 'VALENCISO', 'Mas Perinet',
#        'Chozas Carrascal', 'Alonso del Yerro', 'Clos Figueras',
#        'Bodegas Monte La Reina', 'Ontanon', 'Bodega Elias Mora',
#        'Joan Simo', 'Can Axartell', 'Juan Pinero', 'Mas Llunes',
#        'Bodegas Frontaura', 'Roig Parals', 'Avgvstvs', 'Ramon Bilbao',
#        'Leda', 'Cal Batllet - Celler Ripoll Sans', 'Llopart', 'Portia',
#        'Ostatu', 'Finca Valpiedra', 'Baigorri', 'Vivaltus', 'Comenge',
#        'Collbaix Celler El Moli', 'Martinez Lacuesta', 'Pujanza',
#        'Albet i Noya', 'Olivier Riviere', 'Bodegas Tierra',
#        'Torre de Ona', 'Do Ferreiro (Bodegas Gerardo Mendez)',
#        'Martin Codax', 'Vinedos Hermanos Hernaiz', 'Freixenet',
#        'Azpilicueta', 'Veronica Salgado', 'Clos Galena',
#        'Bodegas Imperiales - Abadia de San Quirce', 'Marta Mate',
#        'Venta Las Vacas', 'Pago Calzadilla', 'Vivanco', 'Fernandez Gao',
#        'Museum', 'Farina', 'Galindo San Millan', 'Bodegas Casa Primicia',
#        "Joan d'Anguera", 'Xaloc', 'Carlos Moro', 'Bodegas Luis Perez',
#        'Ladairo', "Conreria d'Scala Dei", 'Traslascuestas',
#        'Lopez Cristobal', 'Codorniu', 'Sota els Angels', 'Berceo',
#        'Mas Blanch I Jove', 'Carlos Serres', 'David Moreno', 'Edra',
#        'Valdelosfrailes', 'Briego',
#        'Guillem Carol - Cellers Carol Valles', 'Barahonda', 'Particular',
#        'Bodegas Frontonio', 'Bodegas Asenjo & Manso', 'Luis Canas',
#        'Garmon', 'Williams & Humbert', 'Condado de Haza', 'Lustau',
#        'Bodegas Faustino', 'Aster', 'Marques de Tomares',
#        'Quinta Sardonia', 'Abadal', 'Hermanos Pecina', 'Biniagual',
#        'Breca', 'Pradorey', 'Terras Gauda', 'Bodega Tesalia',
#        'Pazo de Rubianes', 'Bodegas Olarra', 'Taron', 'Sonsierra',
#        'Vins Miquel Gelabert', 'El Grillo y La Luna', 'De Moya',
#        'Campillo', 'Jean Leon', 'Bodegas Ateca', 'Bodega Campo Eliseo',
#        'Fernandez de Pierola', 'De Muller', 'Monteabellon',
#        'Pepe Mendoza Casa Agricola', 'Neo', "Terra d'Uro", 'Zarate',
#        'Noelia Bebelia', 'Marti Fabra', 'Palmeri Sicilia',
#        'Mas Que Vinos', 'Bodegas Estraunza', 'Telmo Rodriguez',
#        'Pittacum', 'Bodega Sommos', 'Celler de Capcanes', 'Arinzano',
#        'Pago del Vostal', 'Habla', 'Rodriguez de Vera', 'Callejuela',
#        'El Maestro Sierra', 'Paco & Lola', 'Valtravieso',
#        'Costers del Priorat', 'Bodegas Urium', 'Bodega Otazu',
#        'Oller del Mas', 'Alta Alella', 'Bodegas Clunia', "Ca l'Apotecari",
#        'Josep Grau Viticultor', 'Fos', 'Hacienda Grimon', 'Capafons-Osso',
#        'Raul Perez', 'Dominio de la Vega', 'Juve & Camps',
#        'Mas de les Pereres', 'Guilera',
#        "l'Infernal Combier Fischer Gerin", 'Jorge Piernas', 'Balandro',
#        'M. Antonio de la Riva', 'Espelt', 'Bodegas Arfe', 'Real de Asua',
#        'Vinyes dels Aspres', 'Valserrano', 'Shaya', 'Finca Rio Negro',
#        'Loxera', 'Dominio Fournier', 'Neton', 'Cartoixa de Montsalvat',
#        'El Lagar de Isilla', 'Anibal de Otero', 'Altos del Enebro',
#        'Pago de Larrainzar', 'Albamar', 'Can Bas', 'Atlan & Artisan',
#        'Olivardots', 'Lar de Paula', 'La Val', 'Tres Piedras',
#        'Javi Revert', 'Lambuena', 'Attis', 'San Cobate',
#        'Santa Petronila', 'Jimenez-Landi', 'Hidalgo (La Gitana)', 'Arid',
#        'Bodegas Reyes', 'Hugas de Batlle', 'Bodegas Arrocal',
#        'Buil & Gine', 'Luis A. Rodriguez Vazquez', 'Castell del Remei',
#        'Valdubon', 'Bodegas Y Vinedos Alilian', 'Goyo Garcia Viadero',
#        'Santiago Ruiz', 'Mas Bertran', 'Bodegas Gama', 'Edetaria',
#        'Hacienda Zorita Natural Reserve', 'Can Xanet', 'Alonso & Pedrajo',
#        'Mandia Vell', 'Bodega Juan Carlos Sancha', 'Valdecuevas', 'Mocen',
#        'Estones', 'Inurrieta', 'Naia', 'AGE', 'Navajas',
#        'Vinyes del Terrer', 'Cepas Familiares', 'Dominio de Loalva',
#        'Zifar', 'Bordalas Garcia', 'Rimarts', 'Pinna Fidelis', 'Loess',
#        'Dominio de Anza', 'Samsara', 'Cuentavinas', 'Felix Solis',
#        'El Coto', 'Mar de Frades', 'Montecastro', 'Bodegas La Horra',
#        'Hispano Suizas', 'Murviedro', 'Diez Caballero', 'Vegalfaro',
#        'Palacios Remondo', 'Fernando de Castilla', 'Bohorquez',
#        'Adega Familiar Eladio Pineiro', 'Enrique Mendoza', 'Clos Pons'],
#       dtype=object)

# %%
winery_stats = df.winery.value_counts(ascending=False)
winery_stats
# Out:
# Contino                    457
# Artadi                     261
# La Rioja Alta              254
# Sierra Cantabria           237
# Matarromera                232
#                           ...
# Vina al Lado de la Casa      1
# Sonsierra                    1
# Vins Miquel Gelabert         1
# El Grillo y La Luna          1
# Vivaltus                     1
# Name: winery, Length: 440, dtype: int64

# %%
len(winery_stats)
# Out:
# 440

# %%
len(winery_stats[winery_stats<=10])
# Out:
# 378

# %%
len(winery_stats[winery_stats<=15])
# Out:
# 398

# %%
len(winery_stats[winery_stats<=20])
# Out:
# 404

# %%
winery_stats_less_than_10 = winery_stats[winery_stats<=20]
winery_stats_less_than_10
# Out:
# Clos Mogador               19
# Familia Torres             18
# Pago de Los Capellanes     18
# Teso La Monja              17
# Arzuaga                    16
#                            ..
# Vina al Lado de la Casa     1
# Sonsierra                   1
# Vins Miquel Gelabert        1
# El Grillo y La Luna         1
# Vivaltus                    1
# Name: winery, Length: 404, dtype: int64

# %%
df.winery = df.winery.apply(lambda x: 'other' if x in winery_stats_less_than_10 else x)
len(df.winery.unique())
# Out:
# 37

# %%
df.head(30)
# Out:
#                winery                            wine  year  rating  \
# 0               other                           Tinto  2013     4.9
# 1              Artadi                   Vina El Pison  2018     4.9
# 2        Vega Sicilia                           Unico  2009     4.8
# 3        Vega Sicilia                           Unico  1999     4.8
# 4        Vega Sicilia                           Unico  1996     4.8
# 5        Vega Sicilia                           Unico  1998     4.8
# 6        Vega Sicilia                           Unico  2010     4.8
# 7        Vega Sicilia                           Unico  1995     4.8
# 8        Vega Sicilia  Unico Reserva Especial Edicion  2015     4.8
# 9        Vega Sicilia                           Unico  2011     4.8
# 10       Vega Sicilia  Unico Reserva Especial Edicion  2016     4.8
# 11              other                       El Anejon  2016     4.8
# 12       Vega Sicilia  Unico Reserva Especial Edicion  2018     4.8
# 13       Vega Sicilia                           Unico  1970     4.8
# 14        Toro Albala       Don PX Convento Seleccion  1946     4.8
# 15              other           Cuesta de Las Liebres  2015     4.8
# 16       Vega Sicilia                           Unico  1962     4.8
# 17       Vega Sicilia  Unico Reserva Especial Edicion  2019     4.8
# 18              other                         El Nido  2018     4.8
# 19       Vega Sicilia  Unico Reserva Especial Edicion  2004     4.8
# 20              other                Toneles Moscatel  N.V.     4.8
# 21       Vega Sicilia  Unico Reserva Especial Edicion  2013     4.8
# 22  Dominio de Pingus                          Pingus  2016     4.8
# 23        Toro Albala       Don PX Convento Seleccion  1931     4.8
# 24       Vega Sicilia  Unico Reserva Especial Edicion  2010     4.8
# 25       Vega Sicilia                           Unico  1979     4.8
# 26        Toro Albala            Don PX Pedro Ximenez  1946     4.8
# 27    Alvaro Palacios  L'Ermita Velles Vinyes Priorat  2004     4.8
# 28       Vega Sicilia  Unico Reserva Especial Edicion  2005     4.8
# 29       Vega Sicilia  Unico Reserva Especial Edicion  2020     4.8
#
#     num_reviews country              region       price                  type  \
# 0            58  Espana                Toro   995.00000              Toro Red
# 1            31  Espana      Vino de Espana   313.50000           Tempranillo
# 2          1793  Espana    Ribera del Duero   324.95000  Ribera Del Duero Red
# 3          1705  Espana    Ribera del Duero   692.96000  Ribera Del Duero Red
# 4          1309  Espana    Ribera del Duero   778.06000  Ribera Del Duero Red
# 5          1209  Espana    Ribera del Duero   490.00000  Ribera Del Duero Red
# 6          1201  Espana    Ribera del Duero   349.00000  Ribera Del Duero Red
# 7           926  Espana    Ribera del Duero   810.89000  Ribera Del Duero Red
# 8           643  Espana    Ribera del Duero   345.00000  Ribera Del Duero Red
# 9           630  Espana    Ribera del Duero   315.00000  Ribera Del Duero Red
# 10          591  Espana    Ribera del Duero   514.85000  Ribera Del Duero Red
# 11          454  Espana    Ribera del Duero   105.15000  Ribera Del Duero Red
# 12          438  Espana    Ribera del Duero   430.00000  Ribera Del Duero Red
# 13          417  Espana    Ribera del Duero   925.00000  Ribera Del Duero Red
# 14          398  Espana    Montilla-Moriles   350.00000         Pedro Ximenez
# 15          372  Espana    Ribera del Duero   166.18000  Ribera Del Duero Red
# 16          295  Espana    Ribera del Duero  1620.00000  Ribera Del Duero Red
# 17          250  Espana    Ribera del Duero   431.36000  Ribera Del Duero Red
# 18          217  Espana             Jumilla   195.62738                   Red
# 19          211  Espana    Ribera del Duero   824.43000  Ribera Del Duero Red
# 20          174  Espana  Jerez-Xeres-Sherry   253.00000                Sherry
# 21          172  Espana    Ribera del Duero   570.51000  Ribera Del Duero Red
# 22          145  Espana    Ribera del Duero  1280.00000  Ribera Del Duero Red
# 23          139  Espana    Montilla-Moriles   244.85000         Pedro Ximenez
# 24          125  Espana    Ribera del Duero   719.34000  Ribera Del Duero Red
# 25          118  Espana    Ribera del Duero   815.00000  Ribera Del Duero Red
# 26          103  Espana    Montilla-Moriles   285.86000         Pedro Ximenez
# 27           87  Espana            Priorato  1410.26000           Priorat Red
# 28           87  Espana    Ribera del Duero   813.96000  Ribera Del Duero Red
# 29           84  Espana    Ribera del Duero   435.75000  Ribera Del Duero Red
#
#     body  acidity
# 0    5.0      3.0
# 1    4.0      2.0
# 2    5.0      3.0
# 3    5.0      3.0
# 4    5.0      3.0
# 5    5.0      3.0
# 6    5.0      3.0
# 7    5.0      3.0
# 8    5.0      3.0
# 9    5.0      3.0
# 10   5.0      3.0
# 11   5.0      3.0
# 12   5.0      3.0
# 13   5.0      3.0
# 14   5.0      1.0
# 15   5.0      3.0
# 16   5.0      3.0
# 17   5.0      3.0
# 18   4.0      3.0
# 19   5.0      3.0
# 20   4.0      3.0
# 21   5.0      3.0
# 22   5.0      3.0
# 23   5.0      1.0
# 24   5.0      3.0
# 25   5.0      3.0
# 26   5.0      1.0
# 27   4.0      3.0
# 28   5.0      3.0
# 29   5.0      3.0

# %%
wine_stats = df.wine.value_counts(ascending=False)
wine_stats
# Out:
# Reserva                                467
# Gran Reserva                           458
# Rioja Reserva                          240
# El Viejo                               224
# Valdegines                             223
#                                       ...
# Felix Azpilicueta Coleccion Privada      1
# Cava Cuvee De Prestige Trepat            1
# Las Cenizas Tempranillo                  1
# Arousa                                   1
# Oloroso 30 Years Old V.O.R.S             1
# Name: wine, Length: 768, dtype: int64

# %%
len(wine_stats)
# Out:
# 768

# %%
len(wine_stats[wine_stats>10])
# Out:
# 39

# %%
len(wine_stats[wine_stats<=10])
# Out:
# 729

# %%
wine_stats_less_than_10 = wine_stats[wine_stats<=20]
wine_stats_less_than_10
# Out:
# L'Ermita Velles Vinyes Priorat         18
# Pingus                                 17
# Finca Dofi                             17
# Vina El Pison                          16
# Clos Martinet                          15
#                                        ..
# Felix Azpilicueta Coleccion Privada     1
# Cava Cuvee De Prestige Trepat           1
# Las Cenizas Tempranillo                 1
# Arousa                                  1
# Oloroso 30 Years Old V.O.R.S            1
# Name: wine, Length: 739, dtype: int64

# %%
df.wine = df.wine.apply(lambda x: 'other' if x in wine_stats_less_than_10 else x)
len(df.winery.unique())
# Out:
# 37

# %%
df.head(30)
# Out:
#                winery                            wine  year  rating  \
# 0               other                           Tinto  2013     4.9
# 1              Artadi                           other  2018     4.9
# 2        Vega Sicilia                           Unico  2009     4.8
# 3        Vega Sicilia                           Unico  1999     4.8
# 4        Vega Sicilia                           Unico  1996     4.8
# 5        Vega Sicilia                           Unico  1998     4.8
# 6        Vega Sicilia                           Unico  2010     4.8
# 7        Vega Sicilia                           Unico  1995     4.8
# 8        Vega Sicilia  Unico Reserva Especial Edicion  2015     4.8
# 9        Vega Sicilia                           Unico  2011     4.8
# 10       Vega Sicilia  Unico Reserva Especial Edicion  2016     4.8
# 11              other                           other  2016     4.8
# 12       Vega Sicilia  Unico Reserva Especial Edicion  2018     4.8
# 13       Vega Sicilia                           Unico  1970     4.8
# 14        Toro Albala                           other  1946     4.8
# 15              other                           other  2015     4.8
# 16       Vega Sicilia                           Unico  1962     4.8
# 17       Vega Sicilia  Unico Reserva Especial Edicion  2019     4.8
# 18              other                           other  2018     4.8
# 19       Vega Sicilia  Unico Reserva Especial Edicion  2004     4.8
# 20              other                           other  N.V.     4.8
# 21       Vega Sicilia  Unico Reserva Especial Edicion  2013     4.8
# 22  Dominio de Pingus                           other  2016     4.8
# 23        Toro Albala                           other  1931     4.8
# 24       Vega Sicilia  Unico Reserva Especial Edicion  2010     4.8
# 25       Vega Sicilia                           Unico  1979     4.8
# 26        Toro Albala                           other  1946     4.8
# 27    Alvaro Palacios                           other  2004     4.8
# 28       Vega Sicilia  Unico Reserva Especial Edicion  2005     4.8
# 29       Vega Sicilia  Unico Reserva Especial Edicion  2020     4.8
#
#     num_reviews country              region       price                  type  \
# 0            58  Espana                Toro   995.00000              Toro Red
# 1            31  Espana      Vino de Espana   313.50000           Tempranillo
# 2          1793  Espana    Ribera del Duero   324.95000  Ribera Del Duero Red
# 3          1705  Espana    Ribera del Duero   692.96000  Ribera Del Duero Red
# 4          1309  Espana    Ribera del Duero   778.06000  Ribera Del Duero Red
# 5          1209  Espana    Ribera del Duero   490.00000  Ribera Del Duero Red
# 6          1201  Espana    Ribera del Duero   349.00000  Ribera Del Duero Red
# 7           926  Espana    Ribera del Duero   810.89000  Ribera Del Duero Red
# 8           643  Espana    Ribera del Duero   345.00000  Ribera Del Duero Red
# 9           630  Espana    Ribera del Duero   315.00000  Ribera Del Duero Red
# 10          591  Espana    Ribera del Duero   514.85000  Ribera Del Duero Red
# 11          454  Espana    Ribera del Duero   105.15000  Ribera Del Duero Red
# 12          438  Espana    Ribera del Duero   430.00000  Ribera Del Duero Red
# 13          417  Espana    Ribera del Duero   925.00000  Ribera Del Duero Red
# 14          398  Espana    Montilla-Moriles   350.00000         Pedro Ximenez
# 15          372  Espana    Ribera del Duero   166.18000  Ribera Del Duero Red
# 16          295  Espana    Ribera del Duero  1620.00000  Ribera Del Duero Red
# 17          250  Espana    Ribera del Duero   431.36000  Ribera Del Duero Red
# 18          217  Espana             Jumilla   195.62738                   Red
# 19          211  Espana    Ribera del Duero   824.43000  Ribera Del Duero Red
# 20          174  Espana  Jerez-Xeres-Sherry   253.00000                Sherry
# 21          172  Espana    Ribera del Duero   570.51000  Ribera Del Duero Red
# 22          145  Espana    Ribera del Duero  1280.00000  Ribera Del Duero Red
# 23          139  Espana    Montilla-Moriles   244.85000         Pedro Ximenez
# 24          125  Espana    Ribera del Duero   719.34000  Ribera Del Duero Red
# 25          118  Espana    Ribera del Duero   815.00000  Ribera Del Duero Red
# 26          103  Espana    Montilla-Moriles   285.86000         Pedro Ximenez
# 27           87  Espana            Priorato  1410.26000           Priorat Red
# 28           87  Espana    Ribera del Duero   813.96000  Ribera Del Duero Red
# 29           84  Espana    Ribera del Duero   435.75000  Ribera Del Duero Red
#
#     body  acidity
# 0    5.0      3.0
# 1    4.0      2.0
# 2    5.0      3.0
# 3    5.0      3.0
# 4    5.0      3.0
# 5    5.0      3.0
# 6    5.0      3.0
# 7    5.0      3.0
# 8    5.0      3.0
# 9    5.0      3.0
# 10   5.0      3.0
# 11   5.0      3.0
# 12   5.0      3.0
# 13   5.0      3.0
# 14   5.0      1.0
# 15   5.0      3.0
# 16   5.0      3.0
# 17   5.0      3.0
# 18   4.0      3.0
# 19   5.0      3.0
# 20   4.0      3.0
# 21   5.0      3.0
# 22   5.0      3.0
# 23   5.0      1.0
# 24   5.0      3.0
# 25   5.0      3.0
# 26   5.0      1.0
# 27   4.0      3.0
# 28   5.0      3.0
# 29   5.0      3.0

# %%
df.country.unique()
# Out:
# array(['Espana'], dtype=object)

# %%
df = df.drop('country',axis='columns')

# %%
df.head()
# Out:
#          winery   wine  year  rating  num_reviews            region   price  \
# 0         other  Tinto  2013     4.9           58              Toro  995.00
# 1        Artadi  other  2018     4.9           31    Vino de Espana  313.50
# 2  Vega Sicilia  Unico  2009     4.8         1793  Ribera del Duero  324.95
# 3  Vega Sicilia  Unico  1999     4.8         1705  Ribera del Duero  692.96
# 4  Vega Sicilia  Unico  1996     4.8         1309  Ribera del Duero  778.06
#
#                    type  body  acidity
# 0              Toro Red   5.0      3.0
# 1           Tempranillo   4.0      2.0
# 2  Ribera Del Duero Red   5.0      3.0
# 3  Ribera Del Duero Red   5.0      3.0
# 4  Ribera Del Duero Red   5.0      3.0

# %%
df.year.nunique()
# Out:
# 71

# %%
df.rating.describe()
# Out:
# count    6953.000000
# mean        4.256896
# std         0.120385
# min         4.200000
# 25%         4.200000
# 50%         4.200000
# 75%         4.200000
# max         4.900000
# Name: rating, dtype: float64

# %%
df.region.nunique()
# Out:
# 69

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df.region = le.fit_transform(df.region)
df.region
# Out:
# 0       64
# 1       67
# 2       52
# 3       52
# 4       52
#         ..
# 7495    54
# 7496    49
# 7497    23
# 7498    52
# 7499    52
# Name: region, Length: 6953, dtype: int64

# %%
df.winery = le.fit_transform(df.winery)
df.wine = le.fit_transform(df.wine)

# %%
df['type'] = le.fit_transform(df['type'])

# %%
df.head()
# Out:
#    winery  wine  year  rating  num_reviews  region   price  type  body  \
# 0      36    23  2013     4.9           58      64  995.00    19   5.0
# 1       2    29  2018     4.9           31      67  313.50    18   4.0
# 2      32    24  2009     4.8         1793      52  324.95    11   5.0
# 3      32    24  1999     4.8         1705      52  692.96    11   5.0
# 4      32    24  1996     4.8         1309      52  778.06    11   5.0
#
#    acidity
# 0      3.0
# 1      2.0
# 2      3.0
# 3      3.0
# 4      3.0

# %%
df.shape
df = df[df['year'] != 'N.V.']
df.shape
# Out:
# (6672, 10)

# %%
df['year_old'] = 2024 - pd.to_numeric(df['year'])
# Out:
# <ipython-input-220-5b15b8f6508c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year_old'] = 2024 - pd.to_numeric(df['year'])

# %%
df.head()
# Out:
#    winery  wine  year  rating  num_reviews  region   price  type  body  \
# 0      36    23  2013     4.9           58      64  995.00    19   5.0
# 1       2    29  2018     4.9           31      67  313.50    18   4.0
# 2      32    24  2009     4.8         1793      52  324.95    11   5.0
# 3      32    24  1999     4.8         1705      52  692.96    11   5.0
# 4      32    24  1996     4.8         1309      52  778.06    11   5.0
#
#    acidity  year_old
# 0      3.0        11
# 1      2.0         6
# 2      3.0        15
# 3      3.0        25
# 4      3.0        28

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='viridis')
plt.figure(figsize = (40,10))
plt.show()
# Out:
# <ipython-input-222-6cab83693250>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
df = df.drop(['num_reviews','winery','price'],axis='columns')

# %%
features = [feature for feature in df.columns if feature not in ['type']]

# %%
for feature in features:
    plt.figure(figsize=(24, 6))
    sns.violinplot(x='type', y=feature, data=df)
    plt.title(f'Violin Plot of {feature} vs Type')
    plt.show()

# %%
for feature in features:
    plt.figure(figsize=(24, 6))
    sns.boxplot(x='type', y=feature, data=df)
    plt.title(f'Violin Plot of {feature} vs Type')
    plt.show()

# %%
df.head()
numerical_features = ['wine','body','acidity','year_old']
# Out:
#    wine  year  rating  region  type  body  acidity  year_old
# 0    23  2013     4.9      64    19   5.0      3.0        11
# 1    29  2018     4.9      67    18   4.0      2.0         6
# 2    24  2009     4.8      52    11   5.0      3.0        15
# 3    24  1999     4.8      52    11   5.0      3.0        25
# 4    24  1996     4.8      52    11   5.0      3.0        28

# %%
for feature in features:
    plt.figure(figsize=(24, 6))
    sns.scatterplot(x='type', y=feature, data=df)
    plt.title(f'Violin Plot of {feature} vs Type')
    plt.show()

# %%
numerical_features = ['wine','body','acidity','year_old']
plt.figure(figsize=(24, 6))
df[numerical_features].boxplot()
plt.show()

# %%
Q1 = df[numerical_features].quantile(0.25)
Q3 = df[numerical_features].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# Identify outliers
outliers_mask = (df[numerical_features] < lower_bound) | (df[numerical_features] > upper_bound)

# Remove outliers
df_cleaned = df[~outliers_mask].copy()

# %%
plt.figure(figsize=(24, 6))
df_cleaned[numerical_features].boxplot()
plt.show()

# %%
df.head()
# Out:
#    wine  year  rating  region  type  body  acidity  year_old
# 0    23  2013     4.9      64    19   5.0      3.0        11
# 1    29  2018     4.9      67    18   4.0      2.0         6
# 2    24  2009     4.8      52    11   5.0      3.0        15
# 3    24  1999     4.8      52    11   5.0      3.0        25
# 4    24  1996     4.8      52    11   5.0      3.0        28

# %%
X = df.drop('type',axis='columns')
y = df['type']
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.2, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print("X_train\n")
print(X_train)
print("\nX_test\n")
print(X_test)
# Out:
# X_train
#
# [[-0.55302991 -0.29059821 -0.48144821 ... -0.279714    0.21136996
#    0.29059821]
#  [ 1.29655133  0.57062677 -0.48144821 ...  1.49746887  0.21136996
#   -0.57062677]
#  [-1.169557   -1.15182319 -0.48144821 ... -0.279714    0.21136996
#    1.15182319]
#  ...
#  [ 1.09104231  0.42708927 -0.48144821 ... -0.279714   -4.02953779
#   -0.42708927]
#  [ 0.88553328 -0.5776732   2.78970278 ...  1.49746887  0.21136996
#    0.5776732 ]
#  [-1.37506603 -0.14706071 -0.48144821 ... -0.279714    0.21136996
#    0.14706071]]
#
# X_test
#
# [[-1.169557   -1.15182319 -0.48144821 ... -0.279714    0.21136996
#    1.15182319]
#  [ 1.29655133  0.71416426  1.15412728 ... -0.279714    0.21136996
#   -0.71416426]
#  [ 1.29655133 -0.14706071  0.33633954 ... -0.279714    0.21136996
#    0.14706071]
#  ...
#  [ 0.16625168 -0.29059821 -0.48144821 ... -0.279714    0.21136996
#    0.29059821]
#  [ 1.29655133 -0.14706071  1.15412728 ... -0.279714    0.21136996
#    0.14706071]
#  [ 1.19379682  0.71416426 -0.48144821 ... -0.279714    0.21136996
#   -0.71416426]]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
model_params = {
    'svm': {
        'model': SVC(gamma='auto'),
        'params' : {
            'C': [1,10,20],
            'kernel': ['rbf','linear']
        }
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [1,5,10,20,30,40,100]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    },
    'knn':{
        'model': KNeighborsClassifier(),
        'params' : {
            'n_neighbors' : [1,2,5,10,20]
        }
    },
    'NaiveBayes' : {
        'model': GaussianNB(),
        'params' : {
            'priors' : [None]
        }
    },
    'DecisionTree' : {
        'model': DecisionTreeClassifier(),
        'params' : {
            'criterion' : ['gini','entropy'],
            'splitter' : ['best','random']
        }
    },
}

# %%
scores = []
from sklearn.model_selection import GridSearchCV
for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, Y_train)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })

df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
#                  model  best_score  \
# 0                  svm    0.973580
# 1        random_forest    0.978638
# 2  logistic_regression    0.798014
# 3                  knn    0.956718
# 4           NaiveBayes    0.837737
# 5         DecisionTree    0.982762
#
#                                       best_params
# 0                      {'C': 20, 'kernel': 'rbf'}
# 1                            {'n_estimators': 20}
# 2                                       {'C': 10}
# 3                              {'n_neighbors': 1}
# 4                                {'priors': None}
# 5  {'criterion': 'entropy', 'splitter': 'random'}

# %%
clf.best_score_
# Out:
# 0.9827620582051255

# %%
clf.best_params_
# Out:
# {'criterion': 'entropy', 'splitter': 'random'}
